# %% [markdown]
# <a href="https://colab.research.google.com/github/ChayneThrash/DomainBed/blob/main/DomainBedTesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The below two cells connect to your google drive and copies the dataset. If you are uploading the dataset yourself, skip these.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Limited\ Supervision\ Project/Data/NICO.tar.gz /content/NICO.tar.gz
# !mkdir data
# !tar -xvf /content/NICO_2.tar.gz -C ./data
# Out:
# mkdir: cannot create directory ‘data’: File exists
# Archive:  /content/NICO_2.zip
#    creating: data/NICO_2/
#    creating: data/NICO_2/animal/
#    creating: data/NICO_2/animal/images/
#    creating: data/NICO_2/animal/images/bear/
#    creating: data/NICO_2/animal/images/bear/in_forest/
#   inflating: data/NICO_2/animal/images/bear/in_forest/0.jpg
#   inflating: data/NICO_2/animal/images/bear/in_forest/1.jpg
#   inflating: data/NICO_2/animal/images/bear/in_forest/10.jpg
#   inflating: data/NICO_2/animal/images/bear/in_forest/100.jpg
#   inflating: data/NICO_2/animal/images/bear/in_forest/101.jpg
#  extracting: data/NICO_2/animal/images/bear/in_forest/102.jpg
#   inflating: data/NICO_2/animal/images/bear/in_forest/103.jpg
#   inflating: data/NICO_2/animal/images/bear/in_forest/104.jpg
#   inflating: data/NICO_2/animal/images/bear/in_forest/105.jpg
#   inflating: data/NICO_2/animal/images/bear/in_forest/106.jpg
#   inflating: data/NICO_2/animal/images/bear/in_forest/107.jpg
# ...

# %% [markdown]
# Zip both the domainbed and sweep folders under the project root and upload as domainbed.zip

# %%
# !unzip domainbed.zip
# Out:
# Archive:  domainbed.zip
#  extracting: domainbed/__init__.py
#   inflating: domainbed/__init__.pyc
#   inflating: domainbed/algorithms.py
#   inflating: domainbed/command_launchers.py
#   inflating: domainbed/datasets.py
#   inflating: domainbed/hparams_registry.py
#    creating: domainbed/lib/
#    creating: domainbed/lib/__pycache__/
#   inflating: domainbed/lib/__pycache__/fast_data_loader.cpython-38.pyc
#   inflating: domainbed/lib/__pycache__/misc.cpython-38.pyc
#   inflating: domainbed/lib/__pycache__/query.cpython-38.pyc
#   inflating: domainbed/lib/__pycache__/reporting.cpython-38.pyc
#   inflating: domainbed/lib/__pycache__/wide_resnet.cpython-38.pyc
#   inflating: domainbed/lib/fast_data_loader.py
#   inflating: domainbed/lib/misc.py
#   inflating: domainbed/lib/query.py
#   inflating: domainbed/lib/reporting.py
#   inflating: domainbed/lib/wide_resnet.py
#    creating: domainbed/misc/
#   inflating: domainbed/misc/domain_net_duplicates.txt
# ...

# %%
# !pip install -r domainbed/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.4 MB 32.1 MB/s
# ...
#      |████████████████████████████████| 92 kB 603 kB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 76 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 71 kB 11.4 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 64.4 MB/s
# ...
#      |████████████████████████████████| 78 kB 9.2 MB/s
# ...
#      |████████████████████████████████| 139 kB 80.8 MB/s
# ...
#      |████████████████████████████████| 24.3 MB 55.1 MB/s
# ...
#      |████████████████████████████████| 19.1 MB 32 kB/s
# ...
#      |████████████████████████████████| 19.1 MB 315 kB/s
# ...
#      |████████████████████████████████| 776.3 MB 10 kB/s
# ...
#      |████████████████████████████████| 21.0 MB 116.0 MB/s
# ...
#      |████████████████████████████████| 750.6 MB 20 kB/s
# ...

# %%
# !pip3 install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |███████████████████████         | 834.1 MB 1.3 MB/s eta 0:04:15tcmalloc: large alloc 1147494400 bytes == 0x3a580000 @  0x7fee8b887615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
#      |█████████████████████████████▏  | 1055.7 MB 1.3 MB/s eta 0:01:21tcmalloc: large alloc 1434370048 bytes == 0x7ebd6000 @  0x7fee8b887615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
# ...

# %% [markdown]
# Swap ColoredMNIST_IRM for whichever dataset you are interested in running.

# %%
# !sh sweep/ColoredMNIST_IRM/run.sh delete_incomplete local ./data
# Out:
# Incomplete: sweep/ColoredMNIST_IRM/outputs/3d13814ed255b7fdbd1f4c6c70fa25a9 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 0)
# Incomplete: sweep/ColoredMNIST_IRM/outputs/a836786f4824361f21e3f662aafb4af5 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 1)
# Incomplete: sweep/ColoredMNIST_IRM/outputs/e9b7778f0517379048183eb0c7a5707c ('ColoredMNIST_IRM', 'VRex_RSC', [2], 2)
# Incomplete: sweep/ColoredMNIST_IRM/outputs/7baf29f66bece4c97203607cb7b1df2f ('ColoredMNIST_IRM', 'VRex_RSC', [2], 3)
# Incomplete: sweep/ColoredMNIST_IRM/outputs/cb6156cf573177f2081c44ea68075872 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 4)
# Incomplete: sweep/ColoredMNIST_IRM/outputs/6b3467373ab33dc1fc7c48794558d7e2 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 5)
# Incomplete: sweep/ColoredMNIST_IRM/outputs/7a3caf6f53641c5259b5f1eb84a0cab2 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 6)
# Incomplete: sweep/ColoredMNIST_IRM/outputs/5e66da0430b908dd8a09a296e20ada67 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 7)
# ...

# %%
# !sh sweep/ColoredMNIST_IRM/run.sh launch local ./data
# Out:
# Not launched: sweep/ColoredMNIST_IRM/outputs/3d13814ed255b7fdbd1f4c6c70fa25a9 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 0)
# Not launched: sweep/ColoredMNIST_IRM/outputs/a836786f4824361f21e3f662aafb4af5 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 1)
# Not launched: sweep/ColoredMNIST_IRM/outputs/e9b7778f0517379048183eb0c7a5707c ('ColoredMNIST_IRM', 'VRex_RSC', [2], 2)
# Not launched: sweep/ColoredMNIST_IRM/outputs/7baf29f66bece4c97203607cb7b1df2f ('ColoredMNIST_IRM', 'VRex_RSC', [2], 3)
# Not launched: sweep/ColoredMNIST_IRM/outputs/cb6156cf573177f2081c44ea68075872 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 4)
# Not launched: sweep/ColoredMNIST_IRM/outputs/6b3467373ab33dc1fc7c48794558d7e2 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 5)
# Not launched: sweep/ColoredMNIST_IRM/outputs/7a3caf6f53641c5259b5f1eb84a0cab2 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 6)
# Not launched: sweep/ColoredMNIST_IRM/outputs/5e66da0430b908dd8a09a296e20ada67 ('ColoredMNIST_IRM', 'VRex_RSC', [2], 7)
# ...

# %%
# !zip -r sweep_results.zip sweep/
# Out:
#   adding: VREX_RSC/ (stored 0%)
#   adding: VREX_RSC/outputs/ (stored 0%)
#   adding: VREX_RSC/outputs/a75b4fbfa4e4df7c9ca79c66b012cbd3/ (stored 0%)
#   adding: VREX_RSC/outputs/a75b4fbfa4e4df7c9ca79c66b012cbd3/out.txt (deflated 57%)
#   adding: VREX_RSC/outputs/a75b4fbfa4e4df7c9ca79c66b012cbd3/done (stored 0%)
#   adding: VREX_RSC/outputs/a75b4fbfa4e4df7c9ca79c66b012cbd3/results.jsonl (deflated 91%)
#   adding: VREX_RSC/outputs/a75b4fbfa4e4df7c9ca79c66b012cbd3/err.txt (deflated 13%)
#   adding: VREX_RSC/outputs/b8fac5b0ce91dded39e21480fe8952ae/ (stored 0%)
#   adding: VREX_RSC/outputs/b8fac5b0ce91dded39e21480fe8952ae/out.txt (deflated 57%)
#   adding: VREX_RSC/outputs/b8fac5b0ce91dded39e21480fe8952ae/done (stored 0%)
#   adding: VREX_RSC/outputs/b8fac5b0ce91dded39e21480fe8952ae/results.jsonl (deflated 90%)
#   adding: VREX_RSC/outputs/b8fac5b0ce91dded39e21480fe8952ae/err.txt (deflated 13%)
#   adding: VREX_RSC/outputs/150d18b4b6dbc7c097e0c224b8c2c17a/ (stored 0%)
# ...
