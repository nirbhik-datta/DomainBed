# %% [markdown]
# <a href="https://colab.research.google.com/github/ChayneThrash/DomainBed/blob/main/DomainBedTesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Limited\ Supervision\ Project/Data/PACS.tar.gz /content/PACS.tar.gz
# !mkdir data
# !tar -xvf /content/PACS.tar.gz -C ./data
# Out:
# Streaming output truncated to the last 5000 lines.
# PACS/photo/guitar/063_0045.jpg
# PACS/photo/guitar/063_0046.jpg
# PACS/photo/guitar/063_0047.jpg
# PACS/photo/guitar/063_0048.jpg
# PACS/photo/guitar/063_0049.jpg
# PACS/photo/guitar/063_0050.jpg
# PACS/photo/guitar/063_0051.jpg
# PACS/photo/guitar/063_0052.jpg
# PACS/photo/guitar/063_0053.jpg
# PACS/photo/guitar/063_0054.jpg
# PACS/photo/guitar/063_0055.jpg
# PACS/photo/guitar/063_0056.jpg
# PACS/photo/guitar/063_0059.jpg
# PACS/photo/guitar/063_0061.jpg
# PACS/photo/guitar/063_0062.jpg
# PACS/photo/guitar/063_0065.jpg
# PACS/photo/guitar/063_0067.jpg
# PACS/photo/guitar/063_0068.jpg
# PACS/photo/guitar/063_0069.jpg
# PACS/photo/guitar/063_0071.jpg
# PACS/photo/guitar/063_0072.jpg
# PACS/photo/guitar/063_0073.jpg
# PACS/photo/guitar/063_0074.jpg
# PACS/photo/guitar/063_0075.jpg
# PACS/photo/guitar/063_0076.jpg
# PACS/photo/guitar/063_0077.jpg
# PACS/photo/guitar/063_0078.jpg
# PACS/photo/guitar/063_0079.jpg
# ...

# %%
# !unzip domainbed.zip
# Out:
# Archive:  domainbed.zip
#   inflating: CODE_OF_CONDUCT.md
#   inflating: CONTRIBUTING.md
#  extracting: domainbed/__init__.py
#   inflating: domainbed/__init__.pyc
#   inflating: domainbed/__pycache__/__init__.cpython-38.pyc
#   inflating: domainbed/__pycache__/algorithms.cpython-38.pyc
#   inflating: domainbed/__pycache__/command_launchers.cpython-38.pyc
#   inflating: domainbed/__pycache__/datasets.cpython-38.pyc
#   inflating: domainbed/__pycache__/hparams_registry.cpython-38.pyc
#   inflating: domainbed/__pycache__/model_selection.cpython-38.pyc
#   inflating: domainbed/__pycache__/networks.cpython-38.pyc
#   inflating: domainbed/__pycache__/utilCurrLrn.cpython-38.pyc
#   inflating: domainbed/algorithms.py
#   inflating: domainbed/command_launchers.py
#   inflating: domainbed/datasets.py
#   inflating: domainbed/hparams_registry.py
#   inflating: domainbed/lib/__pycache__/fast_data_loader.cpython-38.pyc
#   inflating: domainbed/lib/__pycache__/misc.cpython-38.pyc
# ...

# %%
# !pip install -r domainbed/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.3 MB 4.6 MB/s
# ...
#      |████████████████████████████████| 92 kB 582 kB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 76 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 71 kB 10.8 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 75.5 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.2 MB/s
# ...
#      |████████████████████████████████| 130 kB 94.7 MB/s
# ...
#      |████████████████████████████████| 24.3 MB 82.0 MB/s
# ...
#      |████████████████████████████████| 19.1 MB 64.8 MB/s
# ...
#      |████████████████████████████████| 19.1 MB 76.7 MB/s
# ...
#      |████████████████████████████████| 21.0 MB 346 kB/s
# ...
#      |████████████████████████████████| 23.2 MB 78.0 MB/s
# ...

# %%
# !pip3 install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#      |███████████████████████         | 834.1 MB 93.7 MB/s eta 0:00:04tcmalloc: large alloc 1147494400 bytes == 0x392aa000 @  0x7ff0dcedb615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
#      |█████████████████████████████▏  | 1055.7 MB 81.0 MB/s eta 0:00:02tcmalloc: large alloc 1434370048 bytes == 0x7d900000 @  0x7ff0dcedb615 0x58ead6 0x4f355e 0x4d222f 0x51041f 0x5b4ee6 0x58ff2e 0x510325 0x5b4ee6 0x58ff2e 0x50d482 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4d00fb 0x50cb8d 0x4bac0a 0x538a76 0x590ae5 0x510280 0x5b4ee6 0x58ff2e 0x50d482 0x5b4ee6 0x58ff2e 0x50c4fc 0x58fd37 0x50ca37 0x5b4ee6 0x58ff2e
# ...

# %%
# !unzip VREX_RSC_1.7.zip
# Out:
# Archive:  VREX_RSC_1.7.zip
#    creating: VREX_RSC_1.7/
#    creating: VREX_RSC_1.7/outputs/
#    creating: VREX_RSC_1.7/outputs/49a7a1b7a88c8d1ad3e9b9e8e2f3c7e1/
#   inflating: VREX_RSC_1.7/outputs/49a7a1b7a88c8d1ad3e9b9e8e2f3c7e1/err.txt
#   inflating: VREX_RSC_1.7/outputs/49a7a1b7a88c8d1ad3e9b9e8e2f3c7e1/results.jsonl
#   inflating: VREX_RSC_1.7/outputs/49a7a1b7a88c8d1ad3e9b9e8e2f3c7e1/out.txt
#  extracting: VREX_RSC_1.7/outputs/49a7a1b7a88c8d1ad3e9b9e8e2f3c7e1/done
#    creating: VREX_RSC_1.7/outputs/f1daf1c4a7fc817422e6ab274254fbda/
#   inflating: VREX_RSC_1.7/outputs/f1daf1c4a7fc817422e6ab274254fbda/err.txt
#   inflating: VREX_RSC_1.7/outputs/f1daf1c4a7fc817422e6ab274254fbda/results.jsonl
#   inflating: VREX_RSC_1.7/outputs/f1daf1c4a7fc817422e6ab274254fbda/out.txt
#  extracting: VREX_RSC_1.7/outputs/f1daf1c4a7fc817422e6ab274254fbda/done
#    creating: VREX_RSC_1.7/outputs/b7bbc5e0be9ccb350201550f0f6f7d17/
# ...

# %%
# !python -m domainbed.scripts.sweep delete_incomplete --datasets PACS --algorithms VRex_RSC --data_dir ./data --command_launcher local --fixed_test_envs 1 --steps 5001 --holdout_fraction 0.1 --n_hparams 2 --n_trials 1 --skip_confirmation --hparams '{"resnet18": true, "freeze_resnet_bn": false, "resnet_dropout": 0, "nonlinear_classifier": false, "data_augmentation": true, "data_augmentation_scheme": "jigen", "drop_vrex_weights_sep":false, "rsc_vrex_toggle": false }' --output_dir "./VREX_RSC/outputs"
# Out:
# WARNING:root:The WILDS package is out of date. Your version is 1.2.2, while the latest version is 2.0.0.
# Not launched: ./VREX_RSC/outputs/d049a8b3877144ec8a0cccc6055e1f3d ('PACS', 'VRex_RSC', [1], 0)
# Not launched: ./VREX_RSC/outputs/67b5dca17afda16fc60871325daf8ff3 ('PACS', 'VRex_RSC', [1], 1)
# 2 jobs: 0 done, 0 incomplete, 2 not launched.
# About to delete 0 jobs.
# Deleting...
# Deleted 0 jobs!

# %%
# !python -m domainbed.scripts.sweep launch --datasets PACS --algorithms VRex_RSC --data_dir ./data --command_launcher local --fixed_test_envs 1 --steps 5001 --holdout_fraction 0.1 --n_hparams 2 --n_trials 1 --skip_confirmation --hparams '{"resnet18": true, "freeze_resnet_bn": false, "resnet_dropout": 0, "nonlinear_classifier": false, "data_augmentation": true, "data_augmentation_scheme": "jigen", "drop_vrex_weights_sep":false, "rsc_vrex_toggle": false }' --output_dir "./VREX_RSC/outputs"
# Out:
# Not launched: ./VREX_RSC/outputs/d049a8b3877144ec8a0cccc6055e1f3d ('PACS', 'VRex_RSC', [1], 0)
# Not launched: ./VREX_RSC/outputs/67b5dca17afda16fc60871325daf8ff3 ('PACS', 'VRex_RSC', [1], 1)
# 2 jobs: 0 done, 0 incomplete, 2 not launched.
# About to launch 2 jobs.
# Launching...
# Making job directories:
# WARNING:root:The WILDS package is out of date. Your version is 1.2.2, while the latest version is 2.0.0.
# Environment:
# 	Python: 3.7.15
# 	PyTorch: 1.7.1+cu110
# 	Torchvision: 0.8.2+cu110
# 	CUDA: 11.0
# 	CUDNN: 8005
# 	NumPy: 1.20.3
# 	PIL: 8.3.2
# Args:
# 	algorithm: VRex_RSC
# 	checkpoint_freq: None
# 	data_dir: ./data
# 	dataset: PACS
# 	holdout_fraction: 0.1
# 	hparams: {"resnet18": true, "freeze_resnet_bn": false, "resnet_dropout": 0, "nonlinear_classifier": false, "data_augmentation": true, "data_augmentation_scheme": "jigen", "drop_vrex_weights_sep":false, "rsc_vrex_toggle": false }
# 	hparams_seed: 0
# 	output_dir: ./VREX_RSC/outputs/d049a8b3877144ec8a0cccc6055e1f3d
# ...

# %%
# !python -m domainbed.scripts.train --algorithm VREx_gradient_muting --data_dir ./data --dataset WILDSCamelyon --holdout_fraction 0.1 --hparams '{"lr": 0.0002748180350891229, "batch_size": 11, "resnet18": true, "freeze_resnet_bn": false, "resnet_dropout": 0, "nonlinear_classifier": false, "data_augmentation": true, "data_augmentation_scheme": "jigen", "vrex_lambda": 500, "vrex_penalty_anneal_iters": 1500, "rsc_b_drop_factor": 0.18, "rsc_f_drop_factor": 0.41 }' --hparams_seed 0 --output_dir sweep/WILDSCamelyon/VREx_gm_lambda_500 --seed 175620820 --steps 5001 --task domain_generalization --val_envs 1 --test_envs 2 --trial_seed 0 --skip_model_save
# Out:
# Environment:
# 	Python: 3.7.15
# 	PyTorch: 1.7.1+cu110
# 	Torchvision: 0.8.2+cu110
# 	CUDA: 11.0
# 	CUDNN: 8005
# 	NumPy: 1.20.3
# 	PIL: 8.3.2
# Args:
# 	algorithm: VREx_gradient_muting
# 	checkpoint_freq: None
# 	data_dir: ./data
# 	dataset: WILDSCamelyon
# 	holdout_fraction: 0.1
# 	hparams: {"lr": 0.0002748180350891229, "batch_size": 11, "resnet18": true, "freeze_resnet_bn": false, "resnet_dropout": 0, "nonlinear_classifier": false, "data_augmentation": true, "data_augmentation_scheme": "jigen", "vrex_lambda": 500, "vrex_penalty_anneal_iters": 1500, "rsc_b_drop_factor": 0.18, "rsc_f_drop_factor": 0.41 }
# 	hparams_seed: 0
# 	output_dir: sweep/WILDSCamelyon/VREx_gm_lambda_500
# 	save_model_every_checkpoint: False
# 	seed: 175620820
# 	skip_model_save: True
# 	steps: 5001
# 	task: domain_generalization
# 	test_envs: [2]
# 	trial_seed: 0
# 	uda_holdout_fraction: 0
# 	val_envs: [1]
# HParams:
# 	batch_size: 11
# 	class_balanced: False
# 	data_augmentation: True
# ...

# %%
# !rm -rf ./sweep/TerraIncognita/outputs

# %%
# !rm -rf ./data

# %%
# !zip -r pacs_test_1.zip VREX_RSC/
# Out:
#   adding: VREX_RSC/ (stored 0%)
#   adding: VREX_RSC/outputs/ (stored 0%)
#   adding: VREX_RSC/outputs/67b5dca17afda16fc60871325daf8ff3/ (stored 0%)
#   adding: VREX_RSC/outputs/67b5dca17afda16fc60871325daf8ff3/results.jsonl (deflated 90%)
#   adding: VREX_RSC/outputs/67b5dca17afda16fc60871325daf8ff3/err.txt (deflated 13%)
#   adding: VREX_RSC/outputs/67b5dca17afda16fc60871325daf8ff3/out.txt (deflated 57%)
#   adding: VREX_RSC/outputs/67b5dca17afda16fc60871325daf8ff3/done (stored 0%)
#   adding: VREX_RSC/outputs/d049a8b3877144ec8a0cccc6055e1f3d/ (stored 0%)
#   adding: VREX_RSC/outputs/d049a8b3877144ec8a0cccc6055e1f3d/results.jsonl (deflated 91%)
#   adding: VREX_RSC/outputs/d049a8b3877144ec8a0cccc6055e1f3d/err.txt (deflated 57%)
#   adding: VREX_RSC/outputs/d049a8b3877144ec8a0cccc6055e1f3d/out.txt (deflated 62%)
#   adding: VREX_RSC/outputs/d049a8b3877144ec8a0cccc6055e1f3d/done (stored 0%)

# %%
import torch
x = torch.ones(5).to('cuda')

# %%
# !nvidia-smi
# Out:
# Mon Oct 10 16:44:24 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0    48W / 400W |   1858MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...
