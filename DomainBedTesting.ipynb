# %% [markdown]
# <a href="https://colab.research.google.com/github/ChayneThrash/DomainBed/blob/main/DomainBedTesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/Limited\ Supervision\ Project/Data/PACS.tar.gz /content/PACS.tar.gz
# !mkdir data
# !tar -xvf /content/PACS.tar.gz -C ./data
# Out:
# Streaming output truncated to the last 5000 lines.
# PACS/photo/guitar/063_0045.jpg
# PACS/photo/guitar/063_0046.jpg
# PACS/photo/guitar/063_0047.jpg
# PACS/photo/guitar/063_0048.jpg
# PACS/photo/guitar/063_0049.jpg
# PACS/photo/guitar/063_0050.jpg
# PACS/photo/guitar/063_0051.jpg
# PACS/photo/guitar/063_0052.jpg
# PACS/photo/guitar/063_0053.jpg
# PACS/photo/guitar/063_0054.jpg
# PACS/photo/guitar/063_0055.jpg
# PACS/photo/guitar/063_0056.jpg
# PACS/photo/guitar/063_0059.jpg
# PACS/photo/guitar/063_0061.jpg
# PACS/photo/guitar/063_0062.jpg
# PACS/photo/guitar/063_0065.jpg
# PACS/photo/guitar/063_0067.jpg
# PACS/photo/guitar/063_0068.jpg
# PACS/photo/guitar/063_0069.jpg
# PACS/photo/guitar/063_0071.jpg
# PACS/photo/guitar/063_0072.jpg
# PACS/photo/guitar/063_0073.jpg
# PACS/photo/guitar/063_0074.jpg
# PACS/photo/guitar/063_0075.jpg
# PACS/photo/guitar/063_0076.jpg
# PACS/photo/guitar/063_0077.jpg
# PACS/photo/guitar/063_0078.jpg
# PACS/photo/guitar/063_0079.jpg
# ...

# %%
# !unzip domainbed.zip
# Out:
# Archive:  domainbed.zip
#   inflating: .gitignore
#   inflating: CODE_OF_CONDUCT.md
#   inflating: CONTRIBUTING.md
#  extracting: domainbed/__init__.py
#   inflating: domainbed/__init__.pyc
#   inflating: domainbed/algorithms.py
#   inflating: domainbed/command_launchers.py
#   inflating: domainbed/datasets.py
#   inflating: domainbed/hparams_registry.py
#   inflating: domainbed/lib/fast_data_loader.py
#   inflating: domainbed/lib/misc.py
#   inflating: domainbed/lib/query.py
#   inflating: domainbed/lib/reporting.py
#   inflating: domainbed/lib/wide_resnet.py
#   inflating: domainbed/misc/domain_net_duplicates.txt
#  extracting: domainbed/misc/test_sweep_data/0657090f9a83ff76efe083a104fde93a/done
#  extracting: domainbed/misc/test_sweep_data/0657090f9a83ff76efe083a104fde93a/err.txt
#   inflating: domainbed/misc/test_sweep_data/0657090f9a83ff76efe083a104fde93a/out.txt
#   inflating: domainbed/misc/test_sweep_data/0657090f9a83ff76efe083a104fde93a/results.jsonl
# ...

# %%
# !pip install -r domainbed/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 15.3 MB 14.2 MB/s
# ...
#      |████████████████████████████████| 92 kB 562 kB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 12.8 MB 55.2 MB/s
# ...
#      |████████████████████████████████| 776.8 MB 17 kB/s
# ...
#      |████████████████████████████████| 76 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 71 kB 9.8 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 59.4 MB/s
# ...
#      |████████████████████████████████| 78 kB 8.9 MB/s
# ...
#      |████████████████████████████████| 130 kB 75.1 MB/s
# ...
#   Created wheel for gdown: filename=gdown-3.13.0-py3-none-any.whl size=9033 sha256=b901be61313c825c964c03bd122db2275c7d6e54906ada4bdaaf71b40d78a108
# ...

# %%
# !python -m domainbed.scripts.train --algorithm ERM --data_dir ./data --dataset NICO_Mixed --holdout_fraction 0.1 --hparams "{ \"resnet18\": true, \"freeze_resnet_bn\": false, \"resnet_dropout\": 0, \"nonlinear_classifier\": false, \"data_augmentation\": true, \"data_augmentation_scheme\": \"jigen\" }" --hparams_seed 0 --output_dir 'sweep/NICO_Mixed/outputs\4be0cab9b3d4c789f561868960a1f547' --seed 669602875 --steps 5001 --task domain_generalization --test_envs 3 --trial_seed 0 --val_envs 2
# Out:
# WARNING:root:The WILDS package is out of date. Your version is 1.2.2, while the latest version is 2.0.0.
# Environment:
# 	Python: 3.7.14
# 	PyTorch: 1.7.1
# 	Torchvision: 0.8.2
# 	CUDA: 10.2
# 	CUDNN: 7605
# 	NumPy: 1.20.3
# 	PIL: 8.3.2
# Args:
# 	algorithm: ERM
# 	checkpoint_freq: None
# 	data_dir: ./data
# 	dataset: NICO_Mixed
# 	holdout_fraction: 0.1
# 	hparams: { "resnet18": true, "freeze_resnet_bn": false, "resnet_dropout": 0, "nonlinear_classifier": false, "data_augmentation": true, "data_augmentation_scheme": "jigen" }
# 	hparams_seed: 0
# 	output_dir: sweep/NICO_Mixed/outputs\4be0cab9b3d4c789f561868960a1f547
# 	save_model_every_checkpoint: False
# 	seed: 669602875
# 	skip_model_save: False
# 	steps: 5001
# 	task: domain_generalization
# 	test_envs: [3]
# 	trial_seed: 0
# 	uda_holdout_fraction: 0
# 	val_envs: [2]
# HParams:
# 	batch_size: 32
# 	class_balanced: False
# 	data_augmentation: True
# 	data_augmentation_scheme: jigen
# 	freeze_resnet_bn: False
# 	lr: 5e-05
# ...

# %%
# !python -m domainbed.scripts.train --algorithm ERM --data_dir ./data --dataset PACS --holdout_fraction 0.1 --hparams "{ \"resnet18\": true, \"freeze_resnet_bn\": false, \"resnet_dropout\": 0, \"nonlinear_classifier\": false, \"data_augmentation\": true, \"data_augmentation_scheme\": \"jigen\" }" --hparams_seed 0 --output_dir 'sweep/PACS/outputs\7db599c45ba791a08d1111753a308f91' --seed 94828300 --steps 5001 --task domain_generalization --test_envs 0 --trial_seed 0
# Out:
# WARNING:root:The WILDS package is out of date. Your version is 1.2.2, while the latest version is 2.0.0.
# Environment:
# 	Python: 3.7.14
# 	PyTorch: 1.7.1
# 	Torchvision: 0.8.2
# 	CUDA: 10.2
# 	CUDNN: 7605
# 	NumPy: 1.20.3
# 	PIL: 8.3.2
# Args:
# 	algorithm: ERM
# 	checkpoint_freq: None
# 	data_dir: ./data
# 	dataset: PACS
# 	holdout_fraction: 0.1
# 	hparams: { "resnet18": true, "freeze_resnet_bn": false, "resnet_dropout": 0, "nonlinear_classifier": false, "data_augmentation": true, "data_augmentation_scheme": "jigen" }
# 	hparams_seed: 0
# 	output_dir: sweep/PACS/outputs\7db599c45ba791a08d1111753a308f91
# 	save_model_every_checkpoint: False
# 	seed: 94828300
# 	skip_model_save: False
# 	steps: 5001
# 	task: domain_generalization
# 	test_envs: [0]
# 	trial_seed: 0
# 	uda_holdout_fraction: 0
# 	val_envs: []
# HParams:
# 	batch_size: 32
# 	class_balanced: False
# 	data_augmentation: True
# 	data_augmentation_scheme: jigen
# 	freeze_resnet_bn: False
# 	lr: 5e-05
# ...
